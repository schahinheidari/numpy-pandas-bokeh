# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Age'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
data['SibSp'].hist(bins=8) #چندتا خواهر و برادر
# Out:
# <AxesSubplot:>

# %%
data['Pclass'].hist(bins=3)
# Out:
# <AxesSubplot:>

# %%
data['Survived'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.set_style('darkgrid')
data['Survived'].hist()
# Out:
# <AxesSubplot:>

# %%
data['Survived'].plot(kind='hist', bins=3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.plot.line(x='Age', y='Pclass', figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data[:5].plot.line(x='Age', y='Pclass', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data[:5].sort_values(['Age']).plot.line(x='Age', y='Pclass', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data.sort_values(['Age']).plot.line(x='Age', y='Pclass', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data.sort_values(['Age']).plot.line(x='Age', y='Fare', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
data.sort_values(['Embarked']).plot.line(x='Embarked', y='Fare', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Embarked'>

# %%
data.plot.scatter(x='Age', y='Fare', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
data.plot.scatter(x='Age', y='Pclass', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %%
data.plot.hexbin(x='Age', y='Pclass', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %%
data.plot.hexbin(x='Age', y='Pclass', gridsize=10, figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>

# %%
data.plot.hexbin(x='Age', y='Fare', gridsize=20, figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].hist(bins=80)
# Out:
# <AxesSubplot:>

# %%
data['Age'].plot.kde() #kernel density
#بر اساس همسایه ها سنجیده میشود
# kernel smooter
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data['Fare'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.hist(figsize=(10,12))
# Out:
# array([[<AxesSubplot:title={'center':'PassengerId'}>,
#         <AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>,
#         <AxesSubplot:title={'center':'Parch'}>],
#        [<AxesSubplot:title={'center':'Fare'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
d2 = data.drop(['PassengerId', 'Fare'], axis=1)
# data.drop(['PassengerId', 'Fare'], axis=1).boxplot(figsize=(12,8))
d2.boxplot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame([1,2,3,7,9,10, 10.7, 15]).quantile([0.25, 0.5, 0.75])

#IQR(10.7 - 3)*1.5 + 10.7
# Out:
#            0
# 0.25   2.750
# 0.50   8.000
# 0.75  10.175

# %%
pd.DataFrame([1,2,3,7,9,10, 10.7, 15]).plot.box()
# 7*1.5=10.5
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame([1,2,3,7,9,10, 10.7, 15]).plot.box()
# Out:
# <AxesSubplot:>
